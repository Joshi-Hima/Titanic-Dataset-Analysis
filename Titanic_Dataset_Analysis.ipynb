# %% [markdown]
# <a href="https://colab.research.google.com/github/Joshi-Hima/Titanic-Dataset-Analysis/blob/main/Titanic_Dataset_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/TechAxis(Data Science)/tested.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
#changing the index to Name

df = pd.read_csv('/content/drive/MyDrive/TechAxis(Data Science)/tested.csv', index_col = 'Name')
df
# Out:
#                                               PassengerId  Survived  Pclass  \
# Name
# Kelly, Mr. James                                      892         0       3
# Wilkes, Mrs. James (Ellen Needs)                      893         1       3
# Myles, Mr. Thomas Francis                             894         0       2
# Wirz, Mr. Albert                                      895         0       3
# Hirvonen, Mrs. Alexander (Helga E Lindqvist)          896         1       3
# ...                                                   ...       ...     ...
# Spector, Mr. Woolf                                   1305         0       3
# Oliva y Ocana, Dona. Fermina                         1306         1       1
# Saether, Mr. Simon Sivertsen                         1307         0       3
# Ware, Mr. Frederick                                  1308         0       3
# Peter, Master. Michael J                             1309         0       3
#
# ...

# %%
df.loc['Kelly, Mr. James']  #the data of this passenger
# Out:
# PassengerId       892
# Survived            0
# Pclass              3
# Sex              male
# Age              34.5
# SibSp               0
# Parch               0
# Ticket         330911
# Fare           7.8292
# Cabin             NaN
# Embarked            Q
# Name: Kelly, Mr. James, dtype: object

# %%
#lets see the gender of Ware, Mr. Frederick

df.loc['Ware, Mr. Frederick', 'Sex']
# Out:
# 'male'

# %%
#Lets see the ticket number of Spector, Mr. Woolf

df.loc['Spector, Mr. Woolf', 'Ticket']
# Out:
# 'A.5. 3236'

# %%
df.head(3)
# Out:
#                                   PassengerId  Survived  Pclass     Sex   Age  \
# Name
# Kelly, Mr. James                          892         0       3    male  34.5
# Wilkes, Mrs. James (Ellen Needs)          893         1       3  female  47.0
# Myles, Mr. Thomas Francis                 894         0       2    male  62.0
#
#                                   SibSp  Parch  Ticket    Fare Cabin Embarked
# Name
# Kelly, Mr. James                      0      0  330911  7.8292   NaN        Q
# Wilkes, Mrs. James (Ellen Needs)      1      0  363272  7.0000   NaN        S
# Myles, Mr. Thomas Francis             0      0  240276  9.6875   NaN        Q

# %%
df
# Out:
#                                               PassengerId  Survived  Pclass  \
# Name
# Kelly, Mr. James                                      892         0       3
# Wilkes, Mrs. James (Ellen Needs)                      893         1       3
# Myles, Mr. Thomas Francis                             894         0       2
# Wirz, Mr. Albert                                      895         0       3
# Hirvonen, Mrs. Alexander (Helga E Lindqvist)          896         1       3
# ...                                                   ...       ...     ...
# Spector, Mr. Woolf                                   1305         0       3
# Oliva y Ocana, Dona. Fermina                         1306         1       1
# Saether, Mr. Simon Sivertsen                         1307         0       3
# Ware, Mr. Frederick                                  1308         0       3
# Peter, Master. Michael J                             1309         0       3
#
# ...

# %%
#sorting index in ascending order

df.sort_index()
# Out:
#                                                PassengerId  Survived  Pclass  \
# Name
# Abbott, Master. Eugene Joseph                         1284         0       3
# Abelseth, Miss. Karen Marie                           1237         1       3
# Abelseth, Mr. Olaus Jorgensen                          949         0       3
# Abrahamsson, Mr. Abraham August Johannes              1143         0       3
# Abrahim, Mrs. Joseph (Sophie Halaut Easu)              900         1       3
# ...                                                    ...       ...     ...
# de Brito, Mr. Jose Joaquim                            1228         0       2
# de Messemaeker, Mr. Guillaume Joseph                  1152         0       3
# del Carlo, Mrs. Sebastiano (Argenia Genovesi)          907         1       2
# van Billiard, Master. James William                   1236         0       3
# van Billiard, Master. Walter John                     1084         0       3
#
# ...

# %%
df.sort_index(ascending = False)
# Out:
#                                                PassengerId  Survived  Pclass  \
# Name
# van Billiard, Master. Walter John                     1084         0       3
# van Billiard, Master. James William                   1236         0       3
# del Carlo, Mrs. Sebastiano (Argenia Genovesi)          907         1       2
# de Messemaeker, Mr. Guillaume Joseph                  1152         0       3
# de Brito, Mr. Jose Joaquim                            1228         0       2
# ...                                                    ...       ...     ...
# Abrahim, Mrs. Joseph (Sophie Halaut Easu)              900         1       3
# Abrahamsson, Mr. Abraham August Johannes              1143         0       3
# Abelseth, Mr. Olaus Jorgensen                          949         0       3
# Abelseth, Miss. Karen Marie                           1237         1       3
# Abbott, Master. Eugene Joseph                         1284         0       3
#
# ...

# %%
#filter the data of male passengers

df['Sex'] == 'male'
# Out:
# Name
# Kelly, Mr. James                                 True
# Wilkes, Mrs. James (Ellen Needs)                False
# Myles, Mr. Thomas Francis                        True
# Wirz, Mr. Albert                                 True
# Hirvonen, Mrs. Alexander (Helga E Lindqvist)    False
#                                                 ...
# Spector, Mr. Woolf                               True
# Oliva y Ocana, Dona. Fermina                    False
# Saether, Mr. Simon Sivertsen                     True
# Ware, Mr. Frederick                              True
# Peter, Master. Michael J                         True
# Name: Sex, Length: 418, dtype: bool

# %%
df[df['Sex'] == 'male']
# Out:
#                               PassengerId  Survived  Pclass   Sex   Age  \
# Name
# Kelly, Mr. James                      892         0       3  male  34.5
# Myles, Mr. Thomas Francis             894         0       2  male  62.0
# Wirz, Mr. Albert                      895         0       3  male  27.0
# Svensson, Mr. Johan Cervin            897         0       3  male  14.0
# Caldwell, Mr. Albert Francis          899         0       2  male  26.0
# ...                                   ...       ...     ...   ...   ...
# Widener, Mr. George Dunton           1299         0       1  male  50.0
# Spector, Mr. Woolf                   1305         0       3  male   NaN
# Saether, Mr. Simon Sivertsen         1307         0       3  male  38.5
# Ware, Mr. Frederick                  1308         0       3  male   NaN
# Peter, Master. Michael J             1309         0       3  male   NaN
#
#                               SibSp  Parch              Ticket      Fare  \
# Name
# ...

# %%
male_passengers = df['Sex'] == 'male'

# %%
df[male_passengers]
# Out:
#                               PassengerId  Survived  Pclass   Sex   Age  \
# Name
# Kelly, Mr. James                      892         0       3  male  34.5
# Myles, Mr. Thomas Francis             894         0       2  male  62.0
# Wirz, Mr. Albert                      895         0       3  male  27.0
# Svensson, Mr. Johan Cervin            897         0       3  male  14.0
# Caldwell, Mr. Albert Francis          899         0       2  male  26.0
# ...                                   ...       ...     ...   ...   ...
# Widener, Mr. George Dunton           1299         0       1  male  50.0
# Spector, Mr. Woolf                   1305         0       3  male   NaN
# Saether, Mr. Simon Sivertsen         1307         0       3  male  38.5
# Ware, Mr. Frederick                  1308         0       3  male   NaN
# Peter, Master. Michael J             1309         0       3  male   NaN
#
#                               SibSp  Parch              Ticket      Fare  \
# Name
# ...

# %%
#how many male passengers were embarked

df.loc[male_passengers, 'Embarked'].value_counts()
# Out:
# Embarked
# S    182
# C     62
# Q     22
# Name: count, dtype: int64

# %%
#how many male passengers survived

df.loc[male_passengers, 'Survived'].value_counts()
# Out:
# Survived
# 0    266
# Name: count, dtype: int64

# %%
male_survived = df.loc[male_passengers, 'Survived'].value_counts()
male_survived.plot.bar()
# Out:
# <Axes: xlabel='Survived'>

# %%
embarked = df.loc[male_passengers, 'Embarked'].value_counts()
embarked.plot.bar()
# Out:
# <Axes: xlabel='Embarked'>

# %%
male_survived.plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
embarked.plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
#showing the male passengers whose id were greater than 1000

greater_than_1000 = df['PassengerId']>1000
df[greater_than_1000]
# Out:
#                               PassengerId  Survived  Pclass     Sex   Age  \
# Name
# Swane, Mr. George                    1001         0       2    male  18.5
# Stanton, Mr. Samuel Ward             1002         0       2    male  41.0
# Shine, Miss. Ellen Natalia           1003         1       3  female   NaN
# Evans, Miss. Edith Corse             1004         1       1  female  36.0
# Buckley, Miss. Katherine             1005         1       3  female  18.5
# ...                                   ...       ...     ...     ...   ...
# Spector, Mr. Woolf                   1305         0       3    male   NaN
# Oliva y Ocana, Dona. Fermina         1306         1       1  female  39.0
# Saether, Mr. Simon Sivertsen         1307         0       3    male  38.5
# Ware, Mr. Frederick                  1308         0       3    male   NaN
# Peter, Master. Michael J             1309         0       3    male   NaN
#
# ...

# %%
#how many of the pasenger id having id more than 1000 were male

male_greater_than_1000 = df.loc[greater_than_1000, 'Sex'].value_counts()
male_greater_than_1000
# Out:
# Sex
# male      198
# female    111
# Name: count, dtype: int64

# %%
male_greater_than_1000.plot.bar()
# Out:
# <Axes: xlabel='Sex'>

# %%
male_greater_than_1000.plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
#How many of them survived

survived = df.loc[greater_than_1000, 'Survived'].value_counts()
survived
# Out:
# Survived
# 0    198
# 1    111
# Name: count, dtype: int64

# %%
survived.plot.bar()
# Out:
# <Axes: xlabel='Survived'>

# %%
survived.plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
df[male_passengers].value_counts()
# Out:
# PassengerId  Survived  Pclass  Sex   Age   SibSp  Parch  Ticket         Fare      Cabin            Embarked
# 920          0         1       male  41.0  0      0      113054         30.5000   A21              S           1
# 1213         0         3       male  25.0  0      0      2654           7.2292    F E57            C           1
# 1137         0         1       male  41.0  1      0      17464          51.8625   D21              S           1
# 1144         0         1       male  27.0  1      0      13508          136.7792  C89              C           1
# 1162         0         1       male  46.0  0      0      13050          75.2417   C6               C           1
# 1179         0         1       male  24.0  1      0      21228          82.2667   B45              S           1
# 1185         0         1       male  53.0  1      1      33638          81.8583   A34              S           1
# ...
